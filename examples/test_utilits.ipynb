# %%
import numpy as np
import dsatools
import dsatools.utilits as ut
from dsatools.generator import harmonics
import matplotlib.pyplot as plt

signal1 = harmonics(amplitude=[3,0.3,1],
                    f0=[0.01,0.1, 1,2,1.4,2.1],
                    length=512,                    
                    delta_f=[0.2,0.1,0.3],
                    snr_db=25)
ut.probe(ut.awgn(signal1,20))
ut.probe(ut.awgnDB(signal1,2))

# %%
import numpy as np
import dsatools
import dsatools.utilits as ut
from dsatools.generator import harmonics
import matplotlib.pyplot as plt

a = np.arange(10)/3.33
print(ut.fixpoint(a,1))
print(ut.fixpoint(a,2))
# Out:
# [0.  0.3 0.6 0.9 1.2 1.5 1.8 2.1 2.4 2.7]
# [0.  0.3 0.6 0.9 1.2 1.5 1.8 2.1 2.4 2.7]

# %%
import numpy as np
import dsatools
import dsatools.utilits as ut

ut.barycenter(np.arange(200,400))
# Out:
# 333.0
