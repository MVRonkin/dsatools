# %%
import dsatools
import dsatools.utilits as ut
from dsatools.frequency import *
fs = 10
signal0 = dsatools.generator.harmonics(amplitude=[1],
                                      f0=[1],
                                      delta_f=[0.0],
                                      fs=fs,
                                      snr_db=10,)
ut.probe(signal0)
x  = signal0
print(fitz_r(signal0,fs=fs))
print(fitz(signal0,fs=fs))
print(mcrb(signal0,fs=fs))
print(m_and_m(signal0,fs=fs))
print(f_and_k(signal0,fs=fs))
print(kay(signal0,fs=fs))
print(tretter_f(signal0,fs=fs))
print(ml_fft(signal0,fs=fs,n_fft=2**18))
print(barycenter_fft(signal0,band=None,fs=fs,n_fft=2**18))
print(barycenter_general_gauss_fft(signal0,sigma=0.5, degree=2,fs=fs,n_fft=2**18))
# Out:
# 1.000055300591047
# 1.0000869588127015
# 1.0000549713923546
# 1.0000549827688507
# 1.0000552550848545
# 1.0000713738705418
# 0.9942203065563318
# 1.00006103515625
# 1.0661773221663426
# 1.0038037200260526

# %%
import sys
import dsatools.utilits as ut
from dsatools._base._frequency import *
import dsatools

fs = 10
signal0 = dsatools.generator.harmonics(amplitude=[1],
                                      f0=[2],
                                      delta_f=[0.0],
                                      fs=fs,
                                      snr_db=8,)
ut.probe(signal0)
x  = signal0
print(dsatools.frequency.maxcorfreq(signal0,fs=fs))
print(dsatools.frequency.maxcorfreq(signal0,fs=fs,with_xcorr=False))
print(dsatools.frequency.maxcorfreq_real(signal0.real,fs=fs))
print(dsatools.frequency.maxcorfreq_real(signal0.real,fs=fs,with_xcorr=False))
# Out:
# 1.9999221340762232
# 2.00467908652937
# 1.9999296271347942
# 2.0760754000508403

# %%
import dsatools
import dsatools.utilits as ut
from dsatools._base._frequency import *
fs = 10
signal0 = dsatools.generator.harmonics(amplitude=[1],
                                      f0=[1],
                                      delta_f=[0.0],
                                      fs=fs,
                                      snr_db=10,)
ut.probe(signal0)
x  = signal0
print(fitz_r(signal0,fs=fs))
print(fitz(signal0,fs=fs))
print(mcrb(signal0,fs=fs))
print(m_and_m(signal0,fs=fs))
print(f_and_k(signal0,fs=fs))
print(kay(signal0,fs=fs))
print(tretter_f(signal0,fs=fs))
print(ml_fft(signal0,fs=fs,n_fft=2**18))
print(barycenter_fft(signal0,band=None,fs=fs,n_fft=2**18))
print(barycenter_general_gauss_fft(signal0,sigma=0.5, degree=2,fs=fs,n_fft=2**18))
# Out:
# 0.9999337413773005
# 0.999949849417541
# 0.9999334222271377
# 0.9999326442286238
# 0.9999304325245624
# 0.9999555440359127
# 0.9941039071137839
# 0.9999465942382812
# 1.0686690600907576
# 1.0041071653237983
