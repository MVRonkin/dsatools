# %%
import dsatools
from dsatools import operators
from dsatools import utilits as ut
from dsatools._base._delay_fmcw import *
signalb1 = dsatools.generator.beatsignal(amplitude=[1],
                      delay=[10.0],
                      delta_delay=[0.0],
                      phase0=[0],
                      f0=1,
                      delta_f=0.5,
                      fs=10,)
dtau = 0.01
signalb2 = dsatools.generator.beatsignal(amplitude=[1],
                      delay=[10.0+dtau],
                      delta_delay=[0.0],
                      phase0=[0],
                      f0=1,
                      delta_f=0.5,
                      fs=10,)
ut.probe(signalb1)

x = signalb1
y = signalb2

print(tau_fullcorrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='R12'))
print(tau_fullcorrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='R21'))
print(tau_fullcorrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='Rfb'))
print(tau_fullcorrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='Rfb12'))
print(tau_fullcorrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='Rfb21'))
# Out:
# 0.009999999999999799
# 0.01101481583740069
# 0.009999999999999802
# 0.009343209892863504
# 0.009999999999999808

# %%
import dsatools
from dsatools import operators
from dsatools import utilits as ut
from dsatools._base._delay_fmcw import *
signalb1 = dsatools.generator.beatsignal(amplitude=[1],
                      delay=[10.0],
                      delta_delay=[0.0],
                      phase0=[0],
                      f0=1,
                      delta_f=0.5,
                      fs=10,)
dtau = 0.01
signalb2 = dsatools.generator.beatsignal(amplitude=[1],
                      delay=[10.0+dtau],
                      delta_delay=[0.0],
                      phase0=[0],
                      f0=1,
                      delta_f=0.5,
                      fs=10,)
ut.probe(signalb1)

x = signalb1
y = signalb2

print(maxcor(x,y,f0=1,delta_f=0.5))
print(maxcor_real(x,y,f0=1,delta_f=0.5))
print(maxcor_unwraped(x,y,f0=1,delta_f=0.5,fs=10, max_tau_scale=3.33))
print(tau_fullphase(x,y,f0=1,delta_f=0.5,fs=10, w_on=True))
print(tau_fullphase(x,y,f0=1,delta_f=0.5,fs=10, w_on=False))
print(tau_unwraped_phase(x,y,f0=1,delta_f=0.5,fs=10, w_on=True, max_tau_scale=3.33))
print(tau_unwraped_phase(x,y,f0=1,delta_f=0.5,fs=10, w_on=False, max_tau_scale=3.33))
# Out:
# 0.009996093749999805
# 0.010055659041123328
# 0.009996093749999805
# 0.009999999999999802
# 0.0099999999999998
# 0.009999999999999802
# 0.0099999999999998
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
import dsatools
from dsatools import operators
from dsatools import utilits as ut
from dsatools._base._delay_fmcw import *
signalb1 = dsatools.generator.beatsignal(amplitude=[1],
                      delay=[10.0],
                      delta_delay=[0.0],
                      phase0=[0],
                      f0=1,
                      delta_f=0.5,
                      fs=10,)
dtau = 0.01
signalb2 = dsatools.generator.beatsignal(amplitude=[1],
                      delay=[10.0+dtau],
                      delta_delay=[0.0],
                      phase0=[0],
                      f0=1,
                      delta_f=0.5,
                      fs=10,)
ut.probe(signalb1)

x = signalb1
y = signalb2


print(tau_unwraped_corrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='R12',max_tau_scale=3.33))
print(tau_unwraped_corrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='R21',max_tau_scale=3.33))
print(tau_unwraped_corrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='Rfb',max_tau_scale=3.33))
print(tau_unwraped_corrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='Rfb12',max_tau_scale=3.33))
print(tau_unwraped_corrphase(x,y,f0=1,delta_f=0.5,Tm=None,fs=10, mode='Rfb21',max_tau_scale=3.33))
# Out:
# 0.00999999999999979
# 0.01101481583740069
# 0.009999999999999806
# 0.009343209892863507
# 0.009999999999999811
